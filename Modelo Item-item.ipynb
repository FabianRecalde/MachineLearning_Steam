# %%
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
from useful_tools import tipo_de_datos

# %% [markdown]
# Para generar nuestro modelo de recomendación utilizaremos como base el dataset "steam_games", sin embargo, agregaremos datos importantes de los otros dos datasets

# %%
# Cargar las tablas desde los archivos parquet
steam_games = pq.read_table("steam_games.parquet").to_pandas()
users_items = pq.read_table("users_items.parquet").to_pandas()
user_reviews = pq.read_table("user_reviews.parquet").to_pandas()

# %% [markdown]
# Comencemos por user_reviews.

# %%
tipo_de_datos.datatype_per_column(user_reviews)
# Out:
# Columna 'user_id': [<class 'str'>]
# Columna 'item_id': [<class 'int'>]
# Columna 'recommend': [<class 'bool'>]
# Columna 'sentiment_analysis': [<class 'int'>]

# %% [markdown]
# Vamos a cambiar el formato y realizar algunas agrupaciones para que los datos nos sean más útiles

# %%
# Convertir True a 1 y False a 0 en la columna 'recommend'
user_reviews['recommend'] = user_reviews['recommend'].astype(int)

# Agrupar los datos por user_id y sumar los valores de recommend y sentiment_analysis
user_reviews = user_reviews.groupby('item_id')[['recommend','sentiment_analysis']].sum().reset_index()

user_reviews
# Out:
#       item_id  recommend  sentiment_analysis
# 0          10         55                  77
# 1          20         11                  21
# 2          30          3                   5
# 3          40          1                   2
# 4          50          3                   6
# ...       ...        ...                 ...
# 3677   521340          2                   4
# 3678   521430          1                   0
# 3679   521570          2                   1
# 3680   521990          1                   2
# 3681   527340          1                   2
#
# [3682 rows x 3 columns]

# %% [markdown]
# Continuemos con users_items

# %%
# Seleccionar las columnas deseadas
users_items = users_items[['item_id', 'playtime_forever']]

# Agrupar los datos por user_id y sumar los valores de playtime_forever
users_items = users_items.groupby('item_id')['playtime_forever'].sum().reset_index()

users_items
# Out:
#        item_id  playtime_forever
# 0           10       4752.182778
# 1           20        266.812222
# 2           30        210.104167
# 3           40         42.895556
# 4           50        201.818056
# ...        ...               ...
# 10045   527570          0.000556
# 10046   527810          0.000556
# 10047   527890          0.000278
# 10048   527900          0.012222
# 10049   528660          0.050556
#
# [10050 rows x 2 columns]

# %% [markdown]
# Por ultimo steam_games. Para que el modelo de similitud del coseno funcione correctamente, utilizaremos solamente el primer genero de la lista para cada juego.

# %%
# Expandir las filas para cada género
steam_games = steam_games.explode('genres')

# Eliminar duplicados por el ID
steam_games = steam_games.drop_duplicates(subset='id')

# Convertir id en entero
steam_games['id'] = steam_games['id'].astype(int)

# Seleccionar las columnas deseadas
steam_games = steam_games[['id','app_name','genres']]

# Eliminar las filas que contienen "no genre" en la columna "genres"
steam_games = steam_games[steam_games['genres'] != 'no genre']

steam_games
# Out:
#             id                  app_name        genres
# 88310   761140       Lost Summoner Kitty        Action
# 88311   643980                 Ironbound  Free to Play
# 88312   670290   Real Pool 3D - Poolians        Casual
# 88313   767400                   弹炸人2222        Action
# 88314   773570             Log Challenge        Action
# ...        ...                       ...           ...
# 120440  773640            Colony On Mars        Casual
# 120441  733530  LOGistICAL: South Africa        Casual
# 120442  610660             Russian Roads         Indie
# 120443  658870       EXIT 2 - Directions        Casual
# 120444  681550               Maze Run VR  Early Access
#
# [31206 rows x 3 columns]

# %% [markdown]
# Ahora agregaremos los datos de users_items y user_reviews al dataframe steam_games

# %%
# Renombrar la columna 'item_id' en users_items y user_reviews
users_items.rename(columns={'item_id': 'user_item_id'}, inplace=True)
user_reviews.rename(columns={'item_id': 'user_item_id'}, inplace=True)

# Fusionar steam_games con users_items en base a la columna 'id' y 'user_item_id'
steam_games = steam_games.merge(users_items, left_on='id', right_on='user_item_id', how='left')

# Fusionar el resultado anterior con user_reviews en base a la columna 'id' y 'user_item_id'
steam_games = steam_games.merge(user_reviews, left_on='id', right_on='user_item_id', how='left')

# Eliminar las columnas 'user_item_id' sobrantes
steam_games.drop(['user_item_id_x', 'user_item_id_y'], axis=1, inplace=True)

# Verificar el resultado
steam_games
# Out:
#            id                  app_name        genres  playtime_forever  \
# 0      761140       Lost Summoner Kitty        Action               NaN
# 1      643980                 Ironbound  Free to Play               NaN
# 2      670290   Real Pool 3D - Poolians        Casual               NaN
# 3      767400                   弹炸人2222        Action               NaN
# 4      773570             Log Challenge        Action               NaN
# ...       ...                       ...           ...               ...
# 31201  773640            Colony On Mars        Casual               NaN
# 31202  733530  LOGistICAL: South Africa        Casual               NaN
# 31203  610660             Russian Roads         Indie               NaN
# 31204  658870       EXIT 2 - Directions        Casual               NaN
# 31205  681550               Maze Run VR  Early Access               NaN
#
#        recommend  sentiment_analysis
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
# ...          ...                 ...
# 31201        NaN                 NaN
# 31202        NaN                 NaN
# 31203        NaN                 NaN
# 31204        NaN                 NaN
# 31205        NaN                 NaN
#
# [31206 rows x 6 columns]

# %%
# Eliminar filas con datos nulos en las columnas especificadas
steam_games.dropna(subset=['playtime_forever', 'recommend', 'sentiment_analysis'], inplace=True)

# Convertir id en entero
steam_games['recommend'] = steam_games['recommend'].astype(int)
steam_games['sentiment_analysis'] = steam_games['sentiment_analysis'].astype(int)

steam_games
# Out:
#            id                                         app_name  genres  \
# 27     282010                             Carmageddon Max Pack  Action
# 28         70                                        Half-Life  Action
# 41       2400                           The Ship: Murder Party  Action
# 55       3800                                    Advent Rising  Action
# 56       1520                                           DEFCON   Indie
# ...       ...                                              ...     ...
# 31180      40                               Deathmatch Classic  Action
# 31181     130                            Half-Life: Blue Shift  Action
# 31186      30                                    Day of Defeat  Action
# 31188   13230  Unreal Tournament 2004: Editor's Choice Edition  Action
# 31189      80                   Counter-Strike: Condition Zero  Action
#
#        playtime_forever  recommend  sentiment_analysis
# 27             2.588611          1                   1
# 28           736.373889         60                  82
# 41           286.374167         22                  29
# 55             3.717778          1                   0
# 56            60.595556          6                   8
# ...                 ...        ...                 ...
# 31180         42.895556          1                   2
# 31181        121.343889          5                   9
# 31186        210.104167          3                   5
# 31188         95.859167          6                   8
# 31189        685.869722          9                  16
#
# [2920 rows x 6 columns]

# %%
# Ordenar el DataFrame por playtime_forever en orden descendente
steam_games_sorted = steam_games.sort_values(by='playtime_forever', ascending=False)

# Seleccionar las primeras mil filas
steam_games = steam_games_sorted.head(1000)

steam_games
# Out:
#            id                               app_name        genres  \
# 1028      730       Counter-Strike: Global Offensive        Action
# 58       4000                            Garry's Mod         Indie
# 30337  105600                               Terraria        Action
# 29365  230410                               Warframe        Action
# 31084     240                 Counter-Strike: Source        Action
# ...       ...                                    ...           ...
# 388     42120  Lead and Gold: Gangs of the Wild West        Action
# 27259  308420                               Ziggurat        Action
# 22439  449140                               Istrolid  Free to Play
# 27974  302380                         Floating Point        Casual
# 20945  360170                       How to Survive 2        Action
#
#        playtime_forever  recommend  sentiment_analysis
# 1028      215532.978889       3429                4926
# 58        122741.951667       1657                2322
# 30337      42499.345556        711                1091
# 29365      34090.792500        557                 865
# 31084      30920.751667        226                 351
# ...                 ...        ...                 ...
# 388           36.067222          0                   0
# 27259         35.911944          8                  16
# 22439         35.814722          5                   9
# 27974         35.686944         14                  16
# 20945         35.624722          1                   2
#
# [1000 rows x 6 columns]

# %%
# Seleccionamos las características numéricas para calcular la similitud del coseno
juegos_features = steam_games[['playtime_forever','recommend','sentiment_analysis']]

# Agregamos el género como características codificadas
juegos_features = pd.concat([juegos_features, pd.get_dummies(steam_games['genres'])], axis=1)

# Normalizamos las características para asegurarnos de que tengan la misma escala
scaler = StandardScaler()
juegos_features_normalized = scaler.fit_transform(juegos_features)

# Calculamos la similitud del coseno entre los juegos
cosine_sim = cosine_similarity(juegos_features_normalized, juegos_features_normalized)

# Convertimos la matriz de similitud en un DataFrame
cosine_sim_df = pd.DataFrame(cosine_sim, index=steam_games['app_name'], columns=steam_games['app_name'])

# %%
cosine_sim_df
# Out:
# app_name                               Counter-Strike: Global Offensive  \
# app_name
# Counter-Strike: Global Offensive                               1.000000
# Garry's Mod                                                    0.981383
# Terraria                                                       0.993541
# Warframe                                                       0.989205
# Counter-Strike: Source                                         0.886644
# ...                                                                 ...
# Lead and Gold: Gangs of the Wild West                         -0.298759
# Ziggurat                                                      -0.241921
# Istrolid                                                      -0.071680
# Floating Point                                                -0.064754
# How to Survive 2                                              -0.291909
#
# app_name                               Garry's Mod  Terraria  Warframe  \
# app_name
# Counter-Strike: Global Offensive          0.981383  0.993541  0.989205
# Garry's Mod                               1.000000  0.962291  0.955754
# Terraria                                  0.962291  1.000000  0.999263
# Warframe                                  0.955754  0.999263  1.000000
# Counter-Strike: Source                    0.882251  0.895727  0.905519
# ...                                            ...       ...       ...
# Lead and Gold: Gangs of the Wild West    -0.371775 -0.199522 -0.162997
# Ziggurat                                 -0.322102 -0.139202 -0.102708
# Istrolid                                 -0.065889 -0.098870 -0.107553
# Floating Point                           -0.059547 -0.093435 -0.102783
# How to Survive 2                         -0.365830 -0.192213 -0.155681
#
# app_name                               Counter-Strike: Source  Left 4 Dead 2  \
# app_name
# Counter-Strike: Global Offensive                     0.886644       0.971509
# Garry's Mod                                          0.882251       0.923937
# Terraria                                             0.895727       0.984295
# Warframe                                             0.905519       0.982092
# Counter-Strike: Source                               1.000000       0.813165
# ...                                                       ...            ...
# Lead and Gold: Gangs of the Wild West                0.007917      -0.192145
# Ziggurat                                             0.045309      -0.125232
# Istrolid                                            -0.120132      -0.104890
# Floating Point                                      -0.120565      -0.098479
# How to Survive 2                                     0.012468      -0.184019
#
# app_name                               PAYDAY 2  Sid Meier's Civilization® V  \
# app_name
# Counter-Strike: Global Offensive       0.941473                     0.691600
# Garry's Mod                            0.886573                     0.686949
# Terraria                               0.956567                     0.657609
# Warframe                               0.952296                     0.645471
# Counter-Strike: Source                 0.735037                     0.563370
# ...                                         ...                          ...
# Lead and Gold: Gangs of the Wild West -0.227808                    -0.460273
# Ziggurat                              -0.156882                    -0.428052
# Istrolid                              -0.095925                    -0.057865
# Floating Point                        -0.088720                    -0.054008
# How to Survive 2                      -0.219197                    -0.456487
#
# app_name                                   Rust  Borderlands 2  ...  \
# app_name                                                        ...
# Counter-Strike: Global Offensive       0.949353       0.967311  ...
# Garry's Mod                            0.893823       0.916626  ...
# Terraria                               0.966403       0.985288  ...
# Warframe                               0.963698       0.985126  ...
# Counter-Strike: Source                 0.763388       0.828051  ...
# ...                                         ...            ...  ...
# Lead and Gold: Gangs of the Wild West -0.187773      -0.143649  ...
# Ziggurat                              -0.117707      -0.076512  ...
# Istrolid                              -0.106414      -0.116683  ...
# Floating Point                        -0.099781      -0.111211  ...
# How to Survive 2                      -0.179256      -0.135481  ...
#
# app_name                               Sol Survivor  \
# app_name
# Counter-Strike: Global Offensive          -0.121167
# Garry's Mod                                0.050571
# Terraria                                  -0.165467
# Warframe                                  -0.179465
# Counter-Strike: Source                    -0.196922
# ...                                             ...
# Lead and Gold: Gangs of the Wild West     -0.354470
# Ziggurat                                  -0.371138
# Istrolid                                  -0.015529
# Floating Point                            -0.018045
# How to Survive 2                          -0.356624
#
# app_name                               Paranautical Activity: Deluxe Atonement Edition  \
# app_name
# Counter-Strike: Global Offensive                                             -0.267809
# Garry's Mod                                                                  -0.344756
# Terraria                                                                     -0.166725
# Warframe                                                                     -0.130213
# Counter-Strike: Source                                                        0.028348
# ...                                                                                ...
# Lead and Gold: Gangs of the Wild West                                         0.999132
# Ziggurat                                                                      0.999351
# Istrolid                                                                     -0.225510
# Floating Point                                                               -0.242022
# How to Survive 2                                                              0.999478
#
# app_name                                   LISA  Painkiller Hell & Damnation  \
# app_name
# Counter-Strike: Global Offensive      -0.103261                    -0.277923
# Garry's Mod                           -0.095168                    -0.353640
# Terraria                              -0.144084                    -0.177330
# Warframe                              -0.157136                    -0.140791
# Counter-Strike: Source                -0.176886                     0.021775
# ...                                         ...                          ...
# Lead and Gold: Gangs of the Wild West -0.330132                     0.999594
# Ziggurat                              -0.344757                     0.998820
# Istrolid                              -0.014390                    -0.223741
# Floating Point                        -0.016549                    -0.240342
# How to Survive 2                      -0.332027                     0.999818
#
# app_name                               Zeno Clash  \
# app_name
# Counter-Strike: Global Offensive        -0.258579
# Garry's Mod                             -0.336702
# Terraria                                -0.156876
# Warframe                                -0.120362
# Counter-Strike: Source                   0.034439
# ...                                           ...
# Lead and Gold: Gangs of the Wild West    0.998524
# Ziggurat                                 0.999737
# Istrolid                                -0.227093
# Floating Point                          -0.243549
# How to Survive 2                         0.998992
#
# app_name                               Lead and Gold: Gangs of the Wild West  \
# app_name
# Counter-Strike: Global Offensive                                   -0.298759
# Garry's Mod                                                        -0.371775
# Terraria                                                           -0.199522
# Warframe                                                           -0.162997
# Counter-Strike: Source                                              0.007917
# ...                                                                      ...
# Lead and Gold: Gangs of the Wild West                               1.000000
# Ziggurat                                                            0.997030
# Istrolid                                                           -0.219918
# Floating Point                                                     -0.236652
# How to Survive 2                                                    0.999955
#
# app_name                               Ziggurat  Istrolid  Floating Point  \
# app_name
# Counter-Strike: Global Offensive      -0.241921 -0.071680       -0.064754
# Garry's Mod                           -0.322102 -0.065889       -0.059547
# Terraria                              -0.139202 -0.098870       -0.093435
# Warframe                              -0.102708 -0.107553       -0.102783
# Counter-Strike: Source                 0.045309 -0.120132       -0.120565
# ...                                         ...       ...             ...
# Lead and Gold: Gangs of the Wild West  0.997030 -0.219918       -0.236652
# Ziggurat                               1.000000 -0.229835       -0.246178
# Istrolid                              -0.229835  1.000000       -0.009638
# Floating Point                        -0.246178 -0.009638        1.000000
# How to Survive 2                       0.997713 -0.221202       -0.237893
#
# app_name                               How to Survive 2
# app_name
# Counter-Strike: Global Offensive              -0.291909
# Garry's Mod                                   -0.365830
# Terraria                                      -0.192213
# Warframe                                      -0.155681
# Counter-Strike: Source                         0.012468
# ...                                                 ...
# Lead and Gold: Gangs of the Wild West          0.999955
# Ziggurat                                       0.997713
# Istrolid                                      -0.221202
# Floating Point                                -0.237893
# How to Survive 2                               1.000000
#
# [1000 rows x 1000 columns]

# %%
cosine_sim_df.to_parquet('cosine_sim_df.parquet')

# %%
def recomendar_juegos(juego, cosine_sim_df, n=5):
    # Verificar si el juego está en el DataFrame
    if juego not in cosine_sim_df.index:
        return(f"El juego '{juego}' no se encuentra en la base de datos.")
    
    # Obtener la fila de similitud del juego dado
    sim_row = cosine_sim_df.loc[juego]
    
    # Ordenar las similitudes en orden descendente y obtener los índices de los juegos más similares
    most_similar_indices = sim_row.drop(juego).sort_values(ascending=False).head(n).index
    
    # Crear una lista con los juegos más similares
    juegos_similares = [juego_similar for juego_similar in most_similar_indices]
    
    return juegos_similares

# %%
# Ejemplo de uso
juego_elegido = 'Counter-Strike'
recomendar_juegos(juego_elegido, cosine_sim_df)
# Out:
# ['Dungeon Defenders',
#  'SMITE®',
#  'Battlefield: Bad Company™ 2',
#  'Borderlands',
#  'TERA']
